# %% [markdown]
# The heart disease dataset is taken from [ Kaggle.com].

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Titanic_data.csv')
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# counting NaN values in each columns  
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#plotting graph to show NaN values
plt.figure(figsize=(10,10))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='coolwarm')
plt.ylabel('NaN count')
# Out:
# Text(86.0, 0.5, 'NaN count')

# %% [markdown]
# ## Data Exploring
# filling incomplete age data by exploring all the data

# %%
#Plotting histograms between features
sns.set_style('white')
sns.countplot(x='Survived',data=df,palette='viridis')

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',hue='Sex',data=df,palette='viridis')

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',hue='Pclass',data=df,palette='coolwarm')

# %%
#plotting box plots
plt.figure(figsize=(10, 12))
sns.boxplot(x='Pclass',y='Age',data=df,palette='winter')

# %%
def impute_age(cols):
    Age = cols[0]
    Pclass = cols[1]
    
    if pd.isnull(Age):

        if Pclass == 1:
            return 37

        elif Pclass == 2:
            return 29

        else:
            return 24

    else:
        return Age

# %%
# replacing NaN values in the age column through observation from box plots

df['Age'] = df[['Age','Pclass']].apply(impute_age,axis=1)

# %%
#the plot shows age column completly filled with data

sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df.drop('Cabin',axis=1,inplace=True)
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df.dropna(inplace=True)
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
#performing one-hot encoding
finalset = pd.get_dummies(df, columns = ['Sex','Embarked'],drop_first=True)
finalset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
#dropping the columns which are not useful

finalset.drop(['Name','Ticket'],axis=1,inplace=True)
finalset
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  Sex_male  \
# 0              1         0       3  22.0      1      0   7.2500         1
# 1              2         1       1  38.0      1      0  71.2833         0
# 2              3         1       3  26.0      0      0   7.9250         0
# 3              4         1       1  35.0      1      0  53.1000         0
# 4              5         0       3  35.0      0      0   8.0500         1
# ..           ...       ...     ...   ...    ...    ...      ...       ...
# 886          887         0       2  27.0      0      0  13.0000         1
# 887          888         1       1  19.0      0      0  30.0000         0
# 888          889         0       3  24.0      1      2  23.4500         0
# 889          890         1       1  26.0      0      0  30.0000         1
# 890          891         0       3  32.0      0      0   7.7500         1
#
#      Embarked_Q  Embarked_S
# 0             0           1
# ...

# %% [markdown]
# #### finalset data can be used to build ML model
